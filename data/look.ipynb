# %% [markdown]
# # Checking the dataset

# %%
import pandas as pd

reviews_df = pd.read_csv("restaurants_combined_reviews_final.csv")
final_df = pd.read_csv("restaurants_final_dataset_updated.csv")

print("Reviews dataset shape:", reviews_df.shape)
print("Final dataset shape:", final_df.shape)
# Out:
# Reviews dataset shape: (1173, 12)
# Final dataset shape: (224, 17)

# %%
reviews_df
# Out:
#                          place_id  \
# 0     ChIJ5SO0EQ0Z6zkRTMnqUebrTqA
# 1     ChIJ5SO0EQ0Z6zkRTMnqUebrTqA
# 2     ChIJ5SO0EQ0Z6zkRTMnqUebrTqA
# 3     ChIJ5SO0EQ0Z6zkRTMnqUebrTqA
# 4     ChIJ5SO0EQ0Z6zkRTMnqUebrTqA
# ...                           ...
# 1168  ChIJQx0tsK8a6zkRVfsW8Wg0xBM
# 1169  ChIJQx0tsK8a6zkRVfsW8Wg0xBM
# 1170  ChIJQx0tsK8a6zkRVfsW8Wg0xBM
# 1171  ChIJQx0tsK8a6zkRVfsW8Wg0xBM
# 1172  ChIJQx0tsK8a6zkRVfsW8Wg0xBM
#
#                                     restaurant_name  \
# 0     Drishya Lounge - Best Lounge in New Baneshwor
# 1     Drishya Lounge - Best Lounge in New Baneshwor
# 2     Drishya Lounge - Best Lounge in New Baneshwor
# 3     Drishya Lounge - Best Lounge in New Baneshwor
# 4     Drishya Lounge - Best Lounge in New Baneshwor
# ...                                             ...
# 1168                Sakotha Woh-Chatamari Fast Food
# 1169                Sakotha Woh-Chatamari Fast Food
# 1170                Sakotha Woh-Chatamari Fast Food
# ...

# %%
final_df
# Out:
#                         place_id                  restaurant_name  \
# 0    ChIJ-RNxuIUZ6zkRsDFn-ciYwkQ           CityScape Garden Grill
# 1    ChIJ09Q2F34Z6zkRLHrFvGWnMV8        Bardali Restro & Meetings
# 2    ChIJ0eBjuSgZ6zkRFrzS1BS9v-w      Nepalaya Rooftop Restaurant
# 3    ChIJ0xX1rSsZ6zkRuZtJOPFTpNE      Crunchy Corner Mid Baneshwo
# 4    ChIJ11f3NxUZ6zkRux1Yb9Tgmbo             SUNDOWN by Karma KTM
# ..                           ...                              ...
# 219  ChIJYTnknOsb6zkRxnFiQt4CFN8           Durbar Coffee & Eatery
# 220  ChIJ-6p-wuYb6zkRi5d8PhptS0M             Durbar Thakali Grill
# 221  ChIJv_9Pr3Qb6zkRj3OehCnTFzk                         Cafe Boh
# 222  ChIJ7ysDSokb6zkRJgcO30l_m-w          HOTEL CENTRAL BHAKTAPUR
# 223  ChIJQx0tsK8a6zkRVfsW8Wg0xBM  Sakotha Woh-Chatamari Fast Food
#
#                                                address   latitude  longitude  \
# 0    Rooftop of Computer Bazaar Next to StarMall, P...  27.706574  85.322985
# ...
